# %%
#create lat and lon columns 
import pandas as pd

pr = pd.read_csv("..//data//pracas.csv")

pr['LATITUDE'] = ""
pr['LONGITUDE'] = ""

pr.to_csv("..//data//praças.csv",index=None)
pr
# Out:
#                                                   Nome  \
# 0                                  PRAÇA AMADOR BUENO
# 1                                        PRAÇA ITÁLIA
# 2                                  PRAÇA OSWALDO CRUZ
# 3         PRAÇA CEL. PAULINO CARLOS DE ARRUDA BOTELHO
# 4                                    PRAÇA DOS POMBOS
# 5                           PRAÇA BARÃO DO RIO BRANCO
# 6                                PRAÇA CORONEL SALLES
# 7                                 PRAÇA SANTOS DUMONT
# 8                                  PRAÇA SÃO BENEDITO
# 9                               PRAÇA DUQUE DE CAXIAS
# 10                                   PRAÇA DA SAUDADE
# 11                              PRAÇA DOS VOLUNTÁRIOS
# 12                              PRAÇA PEDRO DE TOLEDO
# 13                                 PRAÇA ELIAS SALLES
# 14                           PRAÇA DOM JOSÉ MARCONDES
# 15                                PRAÇA ANTONIO PRADO
# ...

# %%
#remove empty lat and lon
import pandas as pd

pracas = pd.read_excel('..//data//processed//praças.xlsx', index_col=None)

pracas = pracas.dropna(subset=['LATITUDE'])

#pracas.to_csv("..//data//processed//pracas.csv",index=None)
pracas
# Out:
#                                                   Nome   LATITUDE  LONGITUDE  \
# 1                                         PRAÇA ITÁLIA -22.032209 -47.890414
# 3          PRAÇA CEL. PAULINO CARLOS DE ARRUDA BOTELHO -22.018397 -47.890248
# 4                                     PRAÇA DOS POMBOS -22.013554 -47.871828
# 5                            PRAÇA BARÃO DO RIO BRANCO -22.013562 -47.890270
# 6                                 PRAÇA CORONEL SALLES -22.016563 -47.889882
# 7                                  PRAÇA SANTOS DUMONT -22.020372 -47.891136
# 8                                   PRAÇA SÃO BENEDITO -22.022243 -47.893199
# 9                                PRAÇA DUQUE DE CAXIAS -21.997775 -47.891423
# 10                                    PRAÇA DA SAUDADE -21.999189 -47.891433
# 11                               PRAÇA DOS VOLUNTÁRIOS -22.020008 -47.890144
# 12                               PRAÇA PEDRO DE TOLEDO -22.020036 -47.889549
# ...
