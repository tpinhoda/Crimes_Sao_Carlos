# %%
import pandas as pd

# %%
escolas_particulares = pd.read_csv('data/escolas_particulares.csv', index_col=None)

# %%
escolas_particulares
# Out:
#                                                  Nome  \
# 0                                  PASSATEMPO COLEGIO
# 1                                  SAO CARLOS COLEGIO
# 2                CURSO NOBRE ESCOLA TECNICA UNIDADE 4
# 3   OCA DOS CURUMINS ESCOLA DE ED INFANTIL E ENSIN...
# 4         CASA DO CAMINHO INSTITUICAO ESPIRITA CRISTA
# ..                                                ...
# 56                        SESI 108 CENTRO EDUCACIONAL
# 57                        SESI 407 CENTRO EDUCACIONAL
# 58  SAO CARLOS INSTITUTO EDUCACIONAL ENSINO FUNDAM...
# 59              LA SALLE SAO CARLOS COLEGIO DIOCESANO
# 60    SANTO ANTONIO DE VILA PRADO CENTRO ASSISTENCIAL
#
#                                             Rua    Num                 Bairro  \
# 0                         RUA MAJOR JOSE INACIO   2481                 CENTRO
# 1                                 RUA EPISCOPAL   1859                 CENTRO
# 2                            AVENIDA SAO CARLOS   2105                 CENTRO
# 3                               RUA DA IMPRENSA    392             VILA FARIA
# 4                              RUA COSTA DO SOL    450      VILA COSTA DO SOL
# ..                                          ...    ...                    ...
# 56                             RUA MAURO TOMAZE    455  RESIDENCIAL ITAMARATI
# 57  RUA CORONEL JOSE AUGUSTO DE OLIVEIRA SALLES   1325            VILA IZABEL
# 58                            RUA CAMPOS SALLES   2029         VILA ELIZABETH
# 59                   AVENIDA JOSE PEREIRA LOPES    252             VILA PRADO
# 60            RUA ANANIAS EVANGELISTA DE TOLEDO    400             VILA PRADO
#
#        Telefone
# 0   19 33717500
# 1   16 33742044
# 2   16 33769858
# 3   16 33715976
# 4   16 33619822
# ..          ...
# 56  16 33078659
# 57  16 33686584
# 58  16 33742300
# 59  16 21075100
# 60  16 33711084
#
# [61 rows x 5 columns]

# %%
escolas_particulares.isna().sum()
# Out:
# Nome        0
# Rua         0
# Num         0
# Bairro      0
# Telefone    0
# dtype: int64

# %%
escolas_particulares['Endereço'] = escolas_particulares['Rua'] + ", " + escolas_particulares['Num'] + ", " + escolas_particulares['Bairro']

# %%
escolas_particulares
# Out:
#                                                  Nome  \
# 0                                  PASSATEMPO COLEGIO
# 1                                  SAO CARLOS COLEGIO
# 2                CURSO NOBRE ESCOLA TECNICA UNIDADE 4
# 3   OCA DOS CURUMINS ESCOLA DE ED INFANTIL E ENSIN...
# 4         CASA DO CAMINHO INSTITUICAO ESPIRITA CRISTA
# ..                                                ...
# 56                        SESI 108 CENTRO EDUCACIONAL
# 57                        SESI 407 CENTRO EDUCACIONAL
# 58  SAO CARLOS INSTITUTO EDUCACIONAL ENSINO FUNDAM...
# 59              LA SALLE SAO CARLOS COLEGIO DIOCESANO
# 60    SANTO ANTONIO DE VILA PRADO CENTRO ASSISTENCIAL
#
#                                             Rua    Num                 Bairro  \
# 0                         RUA MAJOR JOSE INACIO   2481                 CENTRO
# 1                                 RUA EPISCOPAL   1859                 CENTRO
# 2                            AVENIDA SAO CARLOS   2105                 CENTRO
# 3                               RUA DA IMPRENSA    392             VILA FARIA
# 4                              RUA COSTA DO SOL    450      VILA COSTA DO SOL
# ..                                          ...    ...                    ...
# 56                             RUA MAURO TOMAZE    455  RESIDENCIAL ITAMARATI
# 57  RUA CORONEL JOSE AUGUSTO DE OLIVEIRA SALLES   1325            VILA IZABEL
# 58                            RUA CAMPOS SALLES   2029         VILA ELIZABETH
# 59                   AVENIDA JOSE PEREIRA LOPES    252             VILA PRADO
# 60            RUA ANANIAS EVANGELISTA DE TOLEDO    400             VILA PRADO
#
#        Telefone                                           Endereço
# 0   19 33717500               RUA MAJOR JOSE INACIO,  2481, CENTRO
# 1   16 33742044                       RUA EPISCOPAL,  1859, CENTRO
# 2   16 33769858                  AVENIDA SAO CARLOS,  2105, CENTRO
# 3   16 33715976                  RUA DA IMPRENSA,  392, VILA FARIA
# 4   16 33619822          RUA COSTA DO SOL,  450, VILA COSTA DO SOL
# ..          ...                                                ...
# 56  16 33078659      RUA MAURO TOMAZE,  455, RESIDENCIAL ITAMARATI
# 57  16 33686584  RUA CORONEL JOSE AUGUSTO DE OLIVEIRA SALLES,  ...
# 58  16 33742300           RUA CAMPOS SALLES,  2029, VILA ELIZABETH
# 59  16 21075100       AVENIDA JOSE PEREIRA LOPES,  252, VILA PRADO
# 60  16 33711084  RUA ANANIAS EVANGELISTA DE TOLEDO,  400, VILA ...
#
# [61 rows x 6 columns]

# %%
escolas_particulares = escolas_particulares.drop(columns=['Telefone', 'Rua', 'Num', 'Bairro'])

# %%
escolas_particulares
# Out:
#                                                  Nome  \
# 0                                  PASSATEMPO COLEGIO
# 1                                  SAO CARLOS COLEGIO
# 2                CURSO NOBRE ESCOLA TECNICA UNIDADE 4
# 3   OCA DOS CURUMINS ESCOLA DE ED INFANTIL E ENSIN...
# 4         CASA DO CAMINHO INSTITUICAO ESPIRITA CRISTA
# ..                                                ...
# 56                        SESI 108 CENTRO EDUCACIONAL
# 57                        SESI 407 CENTRO EDUCACIONAL
# 58  SAO CARLOS INSTITUTO EDUCACIONAL ENSINO FUNDAM...
# 59              LA SALLE SAO CARLOS COLEGIO DIOCESANO
# 60    SANTO ANTONIO DE VILA PRADO CENTRO ASSISTENCIAL
#
#                                              Endereço
# 0                RUA MAJOR JOSE INACIO,  2481, CENTRO
# 1                        RUA EPISCOPAL,  1859, CENTRO
# 2                   AVENIDA SAO CARLOS,  2105, CENTRO
# 3                   RUA DA IMPRENSA,  392, VILA FARIA
# 4           RUA COSTA DO SOL,  450, VILA COSTA DO SOL
# ..                                                ...
# 56      RUA MAURO TOMAZE,  455, RESIDENCIAL ITAMARATI
# 57  RUA CORONEL JOSE AUGUSTO DE OLIVEIRA SALLES,  ...
# 58           RUA CAMPOS SALLES,  2029, VILA ELIZABETH
# 59       AVENIDA JOSE PEREIRA LOPES,  252, VILA PRADO
# 60  RUA ANANIAS EVANGELISTA DE TOLEDO,  400, VILA ...
#
# [61 rows x 2 columns]

# %%
escolas_particulares.to_csv(r'data/cleaned_data/escolas_particulares.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-5423dbbb3f3d> in <module>()
# ----> 1 escolas_particulares.to_csv(r'data/cleaned_data/escolas_particulares.csv', index=False)
#
# /home/luisa/.local/lib/python3.7/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# /home/luisa/.local/lib/python3.7/site-packages/pandas/io/formats/csvs.py in save(self)
#     181                 self.mode,
#     182                 encoding=self.encoding,
# --> 183                 compression=self.compression,
#     184             )
#     185             close = True
#
# /home/luisa/.local/lib/python3.7/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     397         if encoding:
#     398             # Encoding
# --> 399             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     400         elif is_text:
#     401             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/cleaned_data/escolas_particulares.csv'
