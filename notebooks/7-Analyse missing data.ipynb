# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
crimes = pd.read_csv('data/crimes.csv', index_col=None)
escolas_particulares = pd.read_csv('data/escolas_particulares.csv', index_col=None)
escolas_estaduais = pd.read_csv('data/escolas_estaduais.csv', index_col=None)
pracas = pd.read_excel('data/praças.xlsx', index_col=None)
restaurantes = pd.read_csv('data/restaurantes.csv', index_col=None)
escolas_municipais = pd.read_csv('data/escolas_municipais.csv', index_col=None)
outras_escolas = pd.read_csv('data/outras_escolas.csv', index_col=None)
bares = pd.read_csv('data/bares.csv', index_col=None)
pontos_onibus = pd.read_csv('data/pontos_onibus.csv', index_col=None)

# %% [markdown]
# ## Heatmap of null values

# %% [markdown]
# ### Crimes

# %%
crimes.isna().sum()
# Out:
# Ano                          0
# Num_BO                       0
# Data_ocorrencia_BO           0
# Hora_ocorrencia_BO        1449
# Data_hora_registro_BO        0
# Data_hora_impressao_BO       0
# Período                   4858
# Flagrante                    0
# Status                       0
# Conduta                    135
# Bairro                     451
# Tipo_local                   0
# CEP                       2184
# LOGRADOURO                   0
# Num_logradouro               0
# LATITUDE                     0
# LONGITUDE                    0
# dtype: int64

# %%
crimes['Conduta'].value_counts()
# Out:
# VEICULO                         2725
# TRANSEUNTE                      1802
# ESTABELECIMENTO COMERCIAL        931
# OUTROS                           365
# ESTABELECIMENTO-OUTROS            75
# COLETIVO                          72
# INTERIOR TRANSPORTE COLETIVO      67
# INTERIOR DE VEICULO               64
# INTERIOR ESTABELECIMENTO          59
# ESTABELECIMENTO ENSINO             7
# SAIDINHA DE BANCO                  3
# CONDOMINIO COMERCIAL               2
# CAIXA ELETRÔNICO                   1
# Name: Conduta, dtype: int64

# %%
sns.heatmap(crimes.isnull(), cbar=False)

# %%
msno.matrix(crimes)

# %%
msno.heatmap(crimes)

# %%
msno.bar(crimes)

# %%
msno.dendrogram(crimes)

# %%
crimes['Conduta'].value_counts().plot(kind='barh')

# %% [markdown]
# ### Praças

# %%
pracas.isna().sum()
# Out:
# Nome          0
# LATITUDE     22
# LONGITUDE    22
# Descriçao     3
# dtype: int64

# %%
sns.heatmap(pracas.isnull(), cbar=False)

# %%
msno.matrix(pracas)

# %% [markdown]
# ## Heatmaps

# %%
msno.matrix(escolas_particulares)

# %%
msno.matrix(escolas_estaduais)

# %%
msno.matrix(restaurantes)

# %%
msno.matrix(escolas_municipais)

# %%
msno.matrix(outras_escolas)

# %%
msno.matrix(bares)

# %%
msno.matrix(pontos_onibus)
